# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install streamlit --quiet
# !pip install pyngrok==4.1.1 --quiet
# !pip install streamlit-drawable-canvas --quiet
from pyngrok import ngrok
# Out:
#      |████████████████████████████████| 7.8MB 4.3MB/s
#      |████████████████████████████████| 4.2MB 40.3MB/s
#      |████████████████████████████████| 81kB 8.8MB/s
#      |████████████████████████████████| 174kB 40.8MB/s
#      |████████████████████████████████| 112kB 48.4MB/s
#      |████████████████████████████████| 122kB 45.9MB/s
#      |████████████████████████████████| 71kB 8.6MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.5 which is incompatible.
#   Building wheel for pyngrok (setup.py) ... done
#      |████████████████████████████████| 1.3MB 4.3MB/s

# %%
# %%writefile app.py

import numpy as np
import cv2
from tensorflow.keras.models import load_model
import streamlit as st
from streamlit_drawable_canvas import st_canvas

model=load_model('/content/drive/MyDrive/Minor Project<P.Phani kalyan>/Digit Recognizer.hdf5')

st.title('My Digit Reconizer')
st.markdown('''
Write Digit Downhere
''')

SIZE = 192

Canvas_result = st_canvas(
    fill_color="#ffffff",
    stroke_width=10,
    stroke_color='#ffffff',
    background_color ="#00000",
    height=150,width=150,
    drawing_mode='freedraw',
    key="canvas",
)

if Canvas_result.image_data is not None:
  img=cv2.resize(Canvas_result.image_data.astype('uint8'),(28,28))
  img_rescaling = cv2.resize(img, (SIZE, SIZE), interpolation=cv2.INTER_NEAREST)
  st.write('Input image')
  st.image(img_rescaling)

if st.button('Predict'):
  test_x= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  pred= model.predict(test_x.reshape(1, 28, 28))
  st.write(f'result: {np.argmax(pred[0])}')
  st.bar_chart(pred[0])
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py &
url = ngrok.connect(port='8501')
url
# Out:
# nohup: appending output to 'nohup.out'
# 'http://c929d617cd08.ngrok.io'
